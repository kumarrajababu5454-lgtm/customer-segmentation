# %%
print("Customer Segmentation Project")
# Out:
# Customer Segmentation Project

# %%
import sys

print(sys.version)
print(sys.executable)
# Out:
# 3.13.15 (tags/v3.13.15:4061bc4, Aug  5 2026, 13:05:39) [MSC v.1944 64 bit (AMD64)]
# c:\Users\hp\Desktop\customer-segmentation\.venv\Scripts\python.exe

# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib
import seaborn

print("Pandas:", pd.__version__)
print("NumPy:", np.__version__)
print("Scikit-learn:", sklearn.__version__)
print("Matplotlib:", matplotlib.__version__)
print("Seaborn:", seaborn.__version__)
# Out:
# Pandas: 3.0.5
# NumPy: 2.5.2
# Scikit-learn: 1.9.0
# Matplotlib: 3.11.1
# Seaborn: 0.13.2
